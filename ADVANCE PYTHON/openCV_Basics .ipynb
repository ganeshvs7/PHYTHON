# %% [markdown]
# # OpenCV Basics

# %%
from pathlib import Path
import cv2
import sys

script_dir = Path.cwd()
img_path = script_dir / "image.jpg"

img = cv2.imread(str(img_path))
if img is None:
    print(f"Error: could not load {img_path}")
    sys.exit(1)

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print("Image loaded successfully!")
# Out:
# Image loaded successfully!

# %% [markdown]
# ## Resolution

# %%
height, width, channels = img.shape
print(f"Resolution: {width} x {height}")
# Out:
# Resolution: 640 x 479

# %% [markdown]
# ## Channels

# %%
print(f"Channels: {channels}")
# Out:
# Channels: 3

# %% [markdown]
# ## Shape

# %%
print(img.shape)
# Out:
# (479, 640, 3)

# %% [markdown]
# ## RGB Matrix

# %%
print(img_rgb)
# Out:
# [[[120  53  37]
#   [128   0   4]
#   [179 113 140]
#   ...
#   [153  67  52]
#   [125  38  11]
#   [134  46   6]]
#
#  [[ 84   0   0]
#   [189  47  61]
#   [229 174 197]
#   ...
#   [139  64   0]
#   [191 115  31]
#   [177  99  17]]
#
#  [[154  20  44]
#   [111   0   0]
#   [113  85  97]
#   ...
#   [202 135  22]
#   [180 102  28]
#   [106  19   0]]
#
#  ...
#
#  [[ 52  73 100]
#   [ 52  73 100]
#   [ 52  73 100]
#   ...
#   [ 29  56  86]
#   [ 29  56  86]
#   [ 29  56  86]]
#
#  [[ 50  71  98]
#   [ 50  71  98]
#   [ 50  71  98]
#   ...
#   [ 29  56  86]
#   [ 29  56  86]
#   [ 29  56  86]]
#
#  [[ 47  71  99]
#   [ 47  71  99]
#   [ 47  71  99]
#   ...
#   [ 28  55  85]
#   [ 28  55  85]
#   [ 28  55  85]]]

# %% [markdown]
# ## Split RGB Channels

# %%
b,g,r=cv2.split(img_rgb)
print("Blue Channel:\n",b)
print("Green Channel:\n",g)
print("Red Channel:\n",r)
# Out:
# Blue Channel:
#  [[120 128 179 ... 153 125 134]
#  [ 84 189 229 ... 139 191 177]
#  [154 111 113 ... 202 180 106]
#  ...
#  [ 52  52  52 ...  29  29  29]
#  [ 50  50  50 ...  29  29  29]
#  [ 47  47  47 ...  28  28  28]]
# Green Channel:
#  [[ 53   0 113 ...  67  38  46]
#  [  0  47 174 ...  64 115  99]
#  [ 20   0  85 ... 135 102  19]
#  ...
#  [ 73  73  73 ...  56  56  56]
#  [ 71  71  71 ...  56  56  56]
#  [ 71  71  71 ...  55  55  55]]
# Red Channel:
#  [[ 37   4 140 ...  52  11   6]
#  [  0  61 197 ...   0  31  17]
#  [ 44   0  97 ...  22  28   0]
#  ...
#  [100 100 100 ...  86  86  86]
#  [ 98  98  98 ...  86  86  86]
#  [ 99  99  99 ...  85  85  85]]

# %% [markdown]
# ## imread()

# %%
img2=cv2.imread(str(img_path))
print(img2.shape)
# Out:
# (479, 640, 3)

# %% [markdown]
# ## imwrite()

# %%
cv2.imwrite("output_image.jpg", img)
print("Saved as output_image.jpg")
# Out:
# Saved as output_image.jpg

# %% [markdown]
# ## imshow()

# %%
cv2.imshow("Original Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Show RGB Channels

# %%
cv2.imshow("RGB Image", img_rgb)
cv2.imshow("Blue Channel", b)
cv2.imshow("Green Channel", g)
cv2.imshow("Red Channel", r)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## RGB to BGR

# %%
img_bgr=cv2.cvtColor(img_rgb,cv2.COLOR_RGB2BGR)
cv2.imshow("BGR",img_bgr)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Grayscale

# %%
cv2.imshow("Gray",gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Color Comparison

# %%
cv2.imshow("BGR",img)
cv2.imshow("RGB",img_rgb)
cv2.imshow("Gray",gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # function call

# %%
cv2.imshow("BGR",img)
cv2.imshow("RGB",img_rgb)
cv2.imshow("Gray",gray)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 sfscv2.imshow("BGR",img)
#       2 cv2.imshow("RGB",img_rgb)
#       3 cv2.imshow("Gray",gray)
#
# NameError: name 'sfscv2' is not defined

# %% [markdown]
# # GANESH

# %%
cv2.imshow("BGR",img)
cv2.imshow("RGB",img_rgb)
cv2.imshow("Gray",gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Summary

# %% [markdown]
# - imread(): Reads image
# - imwrite(): Saves image
# - imshow(): Displays image
# - cvtColor(): Converts color spaces
# - split(): Separates color channels
# - shape: Gives height, width and channels.
